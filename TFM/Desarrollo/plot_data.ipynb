# %%
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from dateutil.rrule import rrule, MONTHLY
from pprint import pprint as pp
import json
import os
import shutil
import numpy as np
from collections import defaultdict

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import datetime
plt.ion()

# %%
from modules.aux_functions import *
from modules.global_vars import *
from modules.reservation_management import get_reservation_code
from modules.table_manager import manage_table, write_table_data, get_table_data

# %%
hotel_table_path = TEMP_HOTEL_TABLES_PATH + "Melia Barajas" + "/"

hotel_path = "Dataset/Hoteles/obatch- " + "Melia Barajas"
# Load data
df = pd.read_csv(hotel_path)

# %%
o_df = df.copy()
o_df.columns
# Out:
# Index(['Unnamed: 0', 'stimestamp', 'hotel_id', 'hotel_name', 'date_from',
#        'date_to', 'days_in_advance', 'adults', 'kids', 'room',
#        'room_normalized', 'rate', 'rate_normalized', 'board', 'min_stay',
#        'price', 'currency'],
#       dtype='object')

# %%
df['date'] = pd.to_datetime(df['stimestamp'])
#df.set_index('date', inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=681869, step=1)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

df_aux = df[df['days_in_advance'] <= 30]
df_aux = df_aux[df_aux['room_normalized'] == "Doble Superior"]
df_aux.plot.line('date', 'price', ax=ax, label="Melia Barajas")

# %%
df_aux['price'].max()
# Out:
# 209.0
